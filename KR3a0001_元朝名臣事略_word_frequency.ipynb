# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

from ctext import *
setapikey("demo")


import bs4 as bs
import urllib.request
corp={}
for x in range(0, 10):
    sauce = urllib.request.urlopen('https://www.kanripo.org/text/KR2g0033/00%d#1a' % (x)).read()
    soup = bs.BeautifulSoup(sauce, 'lxml')

    corp[x] = ""
    for paragraph in soup.find_all('p'):
        corp[x]+=paragraph.text


frequency=[]
chapter_list=[]

for i in corp:
    match_count = {} 
    for match in re.finditer(r"太師", corp[i]):
        matched_text = match.group(0) 
        if not matched_text in match_count:
            match_count[matched_text] = 0 
        match_count[matched_text] = match_count[matched_text] + 1
    frequency.append(str(match_count.values()))
    chapter_list.append(int(i))


d = {'Chapter': chapter_list, 'Frequency': frequency}
df = pd.DataFrame(data=d)
df['Frequency'] = df['Frequency'].map(lambda x: x.lstrip('dict_values([').rstrip('])'))
df.index = np.arange(1, len(df)+1)
df.replace('', 0, inplace=True)
df['Frequency'] = df['Frequency'].astype(int)

df
# Out:
#     Chapter  Frequency
# 1         0          1
# 2         1          6
# 3         2          0
# 4         3          7
# 5         4          0
# 6         5          0
# 7         6          5
# 8         7          1
# 9         8          4
# 10        9          0

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

from ctext import *
setapikey("demo")


import bs4 as bs
import urllib.request
corp={}
for x in range(10, 16):
    sauce = urllib.request.urlopen('https://www.kanripo.org/text/KR2g0033/0%d#1a' % (x)).read()
    soup = bs.BeautifulSoup(sauce, 'lxml')

    corp[x] = ""
    for paragraph in soup.find_all('p'):
        corp[x]+=paragraph.text


frequency=[]
chapter_list=[]

for i in corp:
    match_count = {} 
    for match in re.finditer(r"太師", corp[i]):
        matched_text = match.group(0) 
        if not matched_text in match_count:
            match_count[matched_text] = 0 
        match_count[matched_text] = match_count[matched_text] + 1
    frequency.append(str(match_count.values()))
    chapter_list.append(int(i))


d = {'Chapter': chapter_list, 'Frequency': frequency}
df = pd.DataFrame(data=d)
df['Frequency'] = df['Frequency'].map(lambda x: x.lstrip('dict_values([').rstrip('])'))
df.index = np.arange(1, len(df)+1)
df.replace('', 0, inplace=True)
df['Frequency'] = df['Frequency'].astype(int)

df
# Out:
#    Chapter  Frequency
# 1       10          0
# 2       11          0
# 3       12          0
# 4       13          0
# 5       14          2
# 6       15          0
